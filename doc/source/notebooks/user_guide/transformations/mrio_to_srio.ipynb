# %% [markdown]
# # MRIO to SRIO
#
# This notebook extracts one region from the packaged multi-regional IOT test table.

# %%
import mario

mario.set_log_verbosity("critical")

# %%
db = mario.load_test("IOT")

# %% [markdown]
# ## Inspect the starting regions

# %%
db.get_index("Region")
# Out:
# ['Reg1', 'Reg2']

# %% [markdown]
# ## Keep only `Reg1`

# %%
single_region = db.to_single_region("Reg1", inplace=False)
single_region.get_index("Region")
# Out:
# ['Reg1']

# %% [markdown]
# ## Inspect the new value-added and final-demand labels

# %%
single_region.get_index("Factor of production")
# Out:
# ['Taxes', 'Wages', 'Capital', 'imports']

# %%
single_region.get_index("Consumption category")
# Out:
# ['Final demand', 'Final Demand exports', 'Intermediate exports']
