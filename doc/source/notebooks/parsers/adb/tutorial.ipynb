# %% [markdown]
# # ADB
#
# This notebook mirrors the practical ADB parser walkthrough in the documentation.

# %% [markdown]
# ## Main entry point
#
# Use `mario.parse_adb(...)` for the public workflow.

# %% [markdown]
# ## Source
#
# - Official ADB MRIO page: [ADB globalization portal](https://kidb.adb.org/globalization/current)

# %%
import mario

# %% [markdown]
# ## Parse one workbook

# %%
db = mario.parse_adb(
    path="/path/to/ADB_MRIO_2024_74.xlsx",
    table="IOT",
)

# %% [markdown]
# ## Parse from a directory

# %%
db = mario.parse_adb(
    path="/path/to/adb_directory",
    table="IOT",
    year=2024,
    economies=74,
)

# %%
db
