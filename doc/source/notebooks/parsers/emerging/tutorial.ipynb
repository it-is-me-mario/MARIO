# %% [markdown]
# # EMERGING
#
# This notebook mirrors the EMERGING parser guide.

# %% [markdown]
# ## Main entry point
#
# Use `mario.parse_emerging(...)` for parsing and `mario.download_emerging(...)` when you want MARIO to fetch the supported Zenodo bundles.

# %% [markdown]
# ## Source links
#
# - [Zenodo concept 10956622](https://doi.org/10.5281/zenodo.10956622)
# - [Zenodo 10956623](https://doi.org/10.5281/zenodo.10956623)
# - [Zenodo 18518911](https://doi.org/10.5281/zenodo.18518911)

# %%
import mario

# %% [markdown]
# ## Optional download step

# %%
mario.download_emerging(
    path="/path/to/emerging",
    version="2.1",
    years=[2023],
)

# %% [markdown]
# ## Parse one EMERGING bundle

# %%
db = mario.parse_emerging(
    path="/path/to/EMERGING_V2_2023_m.mat",
    table="IOT",
)

# %% [markdown]
# ## Restrict the region set

# %%
db = mario.parse_emerging(
    path="/path/to/emerging_directory",
    table="IOT",
    year=2023,
    regions=["ITA", "DEU", "FRA"],
)
