# %% [markdown]
# # WIOD
#
# This notebook mirrors the WIOD parser guide.

# %% [markdown]
# ## Main entry point
#
# Use `mario.parse_wiod(...)` for the WIOD 2016 multiregional workbooks.

# %% [markdown]
# ## Source links
#
# - [GGDC WIOD 2016 release](https://www.rug.nl/ggdc/valuechain/wiod/wiod-2016-release?lang=en)
# - [IOT file](https://dataverse.nl/api/access/datafile/199104)
# - [SUT file](https://dataverse.nl/api/access/datafile/199100)

# %%
import mario

# %% [markdown]
# ## Optional download step

# %%
mario.download_wiod2016(
    path="/path/to/wiod",
    table="IOT",
)

# %% [markdown]
# ## Parse a WIOD IOT workbook

# %%
db = mario.parse_wiod(
    path="/path/to/WIOT2014_Nov16_ROW.xlsb",
    table="IOT",
)

# %% [markdown]
# ## Parse a WIOD SUT workbook

# %%
db = mario.parse_wiod(
    path="/path/to/intsut14_nov16.xlsb",
    table="SUT",
)
